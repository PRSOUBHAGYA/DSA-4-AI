# %% [markdown]
# # Character Count

# %%
def get_char_count(text):
    char_dict = dict()
    for each in text:
        char_dict[each] = char_dict.get(each,0)+1

    return char_dict

# %%
get_char_count('Hello')
# Out:
# {'H': 1, 'e': 1, 'l': 2, 'o': 1}

# %% [markdown]
# # First Non repeating character

# %%
def get_first_non_repeating_char(text):
    char_count_dict = dict()
    for each in text:
        char_count_dict[each] = char_count_dict.get(each,0)+1

    ans = []
    for key,value in char_count_dict.items():
        if value == 1:
            ans.append(key)
    
    return ans

# %%
get_first_non_repeating_char('This is Soubhagya')
# Out:
# ['T', 'S', 'o', 'u', 'b', 'g', 'y']
