# %% [markdown]
# ## 1. Insert

# %%
s = {'city','country',100,True,11.1}
s
# Out:
# {100, 11.1, True, 'city', 'country'}

# %%
s.add('hello')

# %%
s
# Out:
# {100, 11.1, True, 'city', 'country', 'hello'}

# %% [markdown]
# ## 2. Delete

# %%
s.pop()
# Out:
# True

# %%
s
# Out:
# {100, 11.1, 'city', 'country', 'hello'}

# %%
s.pop()
# Out:
# 'country'

# %%
s
# Out:
# {100, 11.1, 'city', 'hello'}

# %%
s.remove('hello')
s
# Out:
# {100, 11.1, 'city'}
