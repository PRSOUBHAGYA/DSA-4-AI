# %% [markdown]
# # Basic Operations Using Dict

# %% [markdown]
# ## 1. Instertion

# %%
dict1 = {
    'name':'Saroj',
    'age':23,
    'gender':'Male'
}

# %%
dict1['name']
# Out:
# 'Saroj'

# %%
dict1.update({'name':'Pinku'})

# %%
dict1
# Out:
# {'name': 'Pinku', 'age': 23, 'gender': 'Male'}

# %%
dict1.update({'Hometown':'Odisha'})
dict1
# Out:
# {'name': 'Pinku', 'age': 23, 'gender': 'Male', 'Hometown': 'Odisha'}

# %%
dict1.setdefault('name')
# Out:
# 'Pinku'

# %%
val = dict1.setdefault('Salary',12000)
type(val)
# Out:
# int

# %%
val
# Out:
# 12000

# %%
dict1
# Out:
# {'name': 'Pinku',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000}

# %% [markdown]
# ## 2. Searching

# %%
dict1['name']
# Out:
# 'Pinku'

# %%
dict1.get('country')

# %%
dict1
# Out:
# {'name': 'Pinku',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000}

# %%
dict1.get('country','india')
# Out:
# 'india'

# %%
dict1
# Out:
# {'name': 'Pinku',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000}

# %% [markdown]
# ## 3. Update

# %%
dict1.update({'name':'Hahny'})
dict1
# Out:
# {'name': 'Hahny',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000}

# %%
dict1.update({'name':'Hahny','Country':'India'})
dict1
# Out:
# {'name': 'Hahny',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000,
#  'Country': 'India'}

# %%
dict1['name']='Ashu'
dict1
# Out:
# {'name': 'Ashu',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Salary': 12000,
#  'Country': 'India'}

# %% [markdown]
# ## 4. Membership

# %%
for key in dict1:
    print(key)
# Out:
# name
# age
# gender
# Hometown
# Salary
# Country

# %%
for key,value in dict1.items():
    print(key, value)
# Out:
# name Ashu
# age 23
# gender Male
# Hometown Odisha
# Salary 12000
# Country India

# %% [markdown]
# ## 5. Delete

# %%
del dict1['Salary']
dict1
# Out:
# {'name': 'Ashu',
#  'age': 23,
#  'gender': 'Male',
#  'Hometown': 'Odisha',
#  'Country': 'India'}

# %%
dict1.pop('age')
# Out:
# 23

# %%
dict1
# Out:
# {'name': 'Ashu', 'gender': 'Male', 'Hometown': 'Odisha', 'Country': 'India'}

# %%
dict1.popitem()
# Out:
# ('Country', 'India')

# %%
dict1
# Out:
# {'name': 'Ashu', 'gender': 'Male', 'Hometown': 'Odisha'}
