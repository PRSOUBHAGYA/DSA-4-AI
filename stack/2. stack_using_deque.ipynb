# %% [markdown]
# # stack using deque

# %%
from collections import deque

# %%
stack = deque()
stack
# Out:
# deque([])

# %%
len(stack)
# Out:
# 0

# %%
stack.append(5)
stack.append(4)
stack.append(3)
stack.append(2)
stack.append(1)
stack
# Out:
# deque([5, 4, 3, 2, 1])

# %%
stack.pop()
# Out:
# 1

# %%
stack
# Out:
# deque([5, 4, 3, 2])

# %%
stack[-1]
# Out:
# 2
