# %%
def linear_search(arr, key):
    for each in arr:
        if each == key:
            return True
    
    return False

# %%
linear_search([1,9,0,2,2],0)
# Out:
# True

# %%
linear_search([1,9,0,2,2],99)
# Out:
# False
